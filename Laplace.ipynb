# %%
# Import the required modules
from scipy import signal
import matplotlib.pyplot as plt

# Command to plot the figures inline in Jupyter environment
# %matplotlib inline

s1 = signal.lti([100, 0], [1, 10])
w1, mag1, phase1 = signal.bode(s1)

# plot on the figure window
plt.figure()
plt.title("Magnitude of (a)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel("mag [dB]")
plt.grid(linestyle='dashed')
plt.semilogx(w1, mag1)
plt.figure()
plt.title("Phase of (a)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'phase [$^\circ$]')
plt.grid(linestyle='dashed')
plt.semilogx(w1, phase1)
plt.show()

s2 = signal.lti([0.4, 40, 1000], [1, 0, 0])
w2, mag2, phase2 = signal.bode(s2)

# plot on the figure window
plt.figure()
plt.title("Magnitude of (b)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel("mag [dB]")
plt.grid(linestyle='dashed')
plt.semilogx(w2, mag2)
plt.figure()
plt.title("Phase of (b)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'phase [$^\circ$]')
plt.grid(linestyle='dashed')
plt.semilogx(w2, phase2)
plt.show()

s3 = signal.lti([80, 40], [50, 10])
w3, mag3, phase3 = signal.bode(s3)

# plot on the figure window
plt.figure()
plt.title("Magnitude of (c)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel("mag [dB]")
plt.semilogx(w3, mag3)
plt.grid(linestyle='dashed')
plt.figure()
plt.title("Phase of (c)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'phase [$^\circ$]')
plt.grid(linestyle='dashed')
plt.semilogx(w3, phase3)
plt.show()

s4 = signal.lti([5, 120, 400], [1, 0])
w4, mag4, phase4 = signal.bode(s4)

# plot on the figure window
plt.figure()
plt.title("Magnitude of (d)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel("mag [dB]")
plt.grid(linestyle='dashed')
plt.semilogx(w4, mag4)
plt.figure()
plt.title("Phase of (d)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'phase [$^\circ$]')
plt.grid(linestyle='dashed')
plt.semilogx(w4, phase4)
plt.show()

s5 = signal.lti([30, 300], [4, 2400, 200000])
w5, mag5, phase5 = signal.bode(s5)

# plot on the figure window
plt.figure()
plt.title("Magnitude of (e)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel("mag [dB]")
plt.grid(linestyle='dashed')
plt.semilogx(w5, mag5)
plt.figure()
plt.title("Phase of (e)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'phase [$^\circ$]')
plt.grid(linestyle='dashed')
plt.semilogx(w5, phase5)
plt.show()

s6 = signal.lti([100, 0], [5, 1100, 70000, 1000000])
w6, mag6, phase6 = signal.bode(s6)

# plot on the figure window
plt.figure()
plt.title("Magnitude of (f)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel("mag [dB]")
plt.grid(linestyle='dashed')
plt.semilogx(w6, mag6)
plt.figure()
plt.title("Phase of (f)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'phase [$^\circ$]')
plt.grid(linestyle='dashed')
plt.semilogx(w6, phase6)
plt.show()

s7 = signal.lti([2, 200], [5, 5050, 50000])
w7, mag7, phase7 = signal.bode(s7)

# plot on the figure window
plt.figure()
plt.title("Magnitude of (g)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel("mag [dB]")
plt.grid(linestyle='dashed')
plt.semilogx(w7, mag7)
plt.figure()
plt.title("Phase of (g)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel(r'phase [$^\circ$]')
plt.grid(linestyle='dashed')
plt.semilogx(w7, phase7)
plt.show()

# %%
# Import the required modules
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt

# Command to plot the figures inline in Jupyter environment
# %matplotlib inline

# all signals were multiplied by impulse in freq. domain (1), then the inverse laplace tranform was performed

t = np.arange(0, 10, 0.01)

# s1 = ((100 * s) / (10 + s))

s1 = -1000 * np.exp(-10 * t) + 100

# plot on the figure window
plt.figure()
plt.title("Impulse Response of (a)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, s1)
plt.show()

# s2 = ((0.4 * (50 + s)^2) / s^2)

s2 = 1000 * t + 40 + 0.4 * signal.unit_impulse(1)

# plot on the figure window
plt.figure()
plt.title("Impulse Response of (b)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, s2)
plt.show()

# s3 = ((40 + 80 * s) / (10 + 50 * s))

s3 = (8/5) * signal.unit_impulse(1) + (12/25) * np.exp(-t/5)

# plot on the figure window
plt.figure()
plt.title("Impulse Response of (c)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, s3)
plt.show()

# s4 = (((20 + 5 * s) * (20 + s)) / s)

# plot on the figure window
plt.figure()
plt.title("Impulse Response of (d) cannot be plotted")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.show()

# s5 = ((30 * (10 + s)) / ((200 + 2 * s) * (1000 + 2 * s)))

s5 = (147/16) * np.exp(-500 * t) - (27/16) * np.exp(-100 * t)

# plot on the figure window
plt.figure()
plt.title("Impulse Response of (e)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, s5)
plt.show()

# s6 = ((100 * s) / ((100 + 5 * s) * (100 + s)^2))

s6 = (1/16) * np.exp(-100 * t) + np.exp(-100 * t) * 25*t - (1/16) * np.exp(-20 * t)

# plot on the figure window
plt.figure()
plt.title("Impulse Response of (f)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, s6)
plt.show()

# s7 = ((200 + 2 * s) / ((50 + 5 * s) * (1000 + s)))

s7 = (-202/495) * np.exp(-10 * t) + (4040/99) * np.exp(-1000 * t)

# plot on the figure window
plt.figure()
plt.title("Impulse Response of (g)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, s7)
plt.show()

# %%
# Import the required modules
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt

# Command to plot the figures inline in Jupyter environment
# %matplotlib inline

# all signals were multiplied by step in freq. domain (1/s), then the inverse Laplace tranform was performed

t = np.arange(0, 10, 0.01)
s = np.arange(1, 11, 0.01)

# a1, b1 = (1 / s) * ((100 * s) / (10 + s))

a1 = 100 * np.exp(-10 * t)
b1 = (100 * s) / (s * (s + 10))

# plot on the figure window
plt.figure()
plt.title("Step Response of (a)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, a1)
plt.show()
plt.figure()
plt.title("Step Response of (a)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel("Y(s)")
plt.grid(linestyle='dashed')
plt.plot(t, b1)
plt.show()

# a2, b2 = (1 / s) * ((0.4 * (50 + s)^2) / s^2)

a2 = 500 * pow(t, 2) + 40 * t + 0.4
b2 = (0.4 * pow(50 + s, 2)) / (pow(s, 3))

# plot on the figure window
plt.figure()
plt.title("Step Response of (b)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, a2)
plt.show()
plt.figure()
plt.title("Step Response of (b)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel("Y(s)")
plt.grid(linestyle='dashed')
plt.plot(t, b2)
plt.show()

# a3, b3 = (1 / s) * ((40 + 80 * s) / (10 + 50 * s))

a3 = 4 - (12/5) * np.exp(-t/5)
b3 = (40 + 80 * s) / (s * (10 + 50 * s))

# plot on the figure window
plt.figure()
plt.title("Step Response of (c)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, a3)
plt.show()
plt.figure()
plt.title("Step Response of (c)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel("Y(s)")
plt.grid(linestyle='dashed')
plt.plot(t, b3)
plt.show()

# a4, b4 = (1 / s) * (((20 + 5 * s) * (20 + s)) / s)

a4 = 400 * t + 120 + 5 * signal.unit_impulse(1)
b4 = ((20 + 5 * s) * (20 + s)) / (pow(s, 2))

# plot on the figure window
plt.figure()
plt.title("Step Response of (d)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, a4)
plt.show()
plt.figure()
plt.title("Step Response of (d)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel("Y(s)")
plt.grid(linestyle='dashed')
plt.plot(t, b4)
plt.show()

# a5, b5 = (1 / s) * ((30 * (10 + s)) / ((200 + 2 * s) * (1000 + 2 * s)))

a5 = (27/1600) * np.exp(-100 * t) - (147/8000) * np.exp(-500 * t) + (3/2000)
b5 = (30 * (10 + s)) / (s * (200 + 2 * s) * (1000 + 2 * s))

# plot on the figure window
plt.figure()
plt.title("Step Response of (e)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, a5)
plt.show()
plt.figure()
plt.title("Step Response of (e)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel("Y(s)")
plt.grid(linestyle='dashed')
plt.plot(t, b5)
plt.show()

# a6, b6 = (1 / s) * ((100 * s) / ((100 + 5 * s) * (100 + s)^2))

a6 = (1/320) * np.exp(-100 * t) - (np.exp(-100 * t) * t / 4) + (1/320) * np.exp(-20 * t)
b6 = (100 * s) / (s * (100 + 5 * s) * pow(100 + s, 2))

# plot on the figure window
plt.figure()
plt.title("Step Response of (f)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, a6)
plt.show()
plt.figure()
plt.title("Step Response of (f)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel("Y(s)")
plt.grid(linestyle='dashed')
plt.plot(t, b6)
plt.show()

# a7, b7 = (1 / s) * ((200 + 2 * s) / ((50 + 5 * s) * (1000 + s)))

a7 = (-1/275) * np.exp(-10 * t) - ((1/2750) * np.exp(-1000 * t)) + (1/250)
b7 = (200 + 2 * s) / (s * (50 + 5 * s) * (1000 + s))

# plot on the figure window
plt.figure()
plt.title("Step Response of (g)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, a7)
plt.show()
plt.figure()
plt.title("Step Response of (g)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel(r'$\omega$ [rad/s]')
plt.ylabel("Y(s)")
plt.grid(linestyle='dashed')
plt.plot(t, b7)
plt.show()

# %%
# Import the required modules
from scipy import signal
import numpy as np
import matplotlib.pyplot as plt

# Command to plot the figures inline in Jupyter environment
# %matplotlib inline

# all signals were multiplied by sinusoid in freq. domain (s / (s^2 + w^2)), then the inverse Laplace tranform was performed

# frequencies were chosen such that it encompasses different regions
# of the magnitude Bode plot to highlight its characteristics

# a1 = (s / (s^2 + 1^2)) * ((100 * s) / (10 + s))
# a2 = (s / (s^2 + 10^2)) * ((100 * s) / (10 + s))
# a3 = (s / (s^2 + 100^2)) * ((100 * s) / (10 + s))

t = np.arange(0, 4*np.pi/1, 0.001)
a1 = 100*((100*np.exp(-10*t)/101)+(1/101)*(np.cos(t)-10*np.sin(t)))
plt.figure()
plt.title("Sinusoid Response of (a)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, np.real(a1), label=r'$\omega$ = 1')
plt.legend(loc='upper left')
plt.show()
t = np.arange(0, 4*np.pi/10, 0.001)
a2 = 100*((np.exp(-10*t)/2)+(1/2)*(np.cos(10*t)-np.sin(10*t)))
plt.figure()
plt.title("Sinusoid Response of (a)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, a2, label=r'$\omega$ = 10')
plt.legend(loc='upper left')
plt.show()
t = np.arange(0, 4*np.pi/100, 0.001)
a3 = 100*((100*np.exp(-10*t)/101)+(10/101)*(10*np.cos(100*t)-np.sin(100*t)))
plt.figure()
plt.title("Sinusoid Response of (a)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, a3, label=r'$\omega$ = 100')
plt.legend(loc='upper left')
plt.show()

# b1 = (s / (s^2 + 1^2)) * ((0.4 * (50 + s)^2) / s^2)
# b2 = (s / (s^2 + 10^2)) * ((0.4 * (50 + s)^2) / s^2)
# b3 = (s / (s^2 + 100^2)) * ((0.4 * (50 + s)^2) / s^2)

t = np.arange(0, 4*np.pi/1, 0.001)
b1 = 0.4*(100*np.sin(t)-2499*np.cos(t)+2500)
plt.figure()
plt.title("Sinusoid Response of (b)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, b1, label=r'$\omega$ = 1')
plt.legend(loc='upper left')
plt.show()
t = np.arange(0, 4*np.pi/10, 0.001)
b2 = 0.4*(10*np.sin(10*t)-24*np.cos(10*t)+25)
plt.figure()
plt.title("Sinusoid Response of (b)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, b2, label=r'$\omega$ = 10')
plt.legend(loc='upper left')
plt.show()
t = np.arange(0, 4*np.pi/100, 0.001)
b3 = 0.1*(4*np.sin(100*t)+3*np.cos(100*t)+1)
plt.figure()
plt.title("Sinusoid Response of (b)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, b3, label=r'$\omega$ = 100')
plt.legend(loc='upper left')
plt.show()

# c1 = (s / (s^2 + 1^2)) * ((40 + 80 * s) / (10 + 50 * s))
# c2 = (s / (s^2 + 10^2)) * ((40 + 80 * s) / (10 + 50 * s))
# c3 = (s / (s^2 + 100^2)) * ((40 + 80 * s) / (10 + 50 * s))

t = np.arange(0, 4*np.pi/1, 0.001)
c1 = (2/13)*(3*np.sin(t)+11*np.cos(t))-(6*np.exp(-t/5)/65)
plt.figure()
plt.title("Sinusoid Response of (c)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, c1, label=r'$\omega$ = 1')
plt.legend(loc='upper left')
plt.show()
t = np.arange(0, 4*np.pi/10, 0.001)
c2 = ((4*(30*np.sin(10*t))+1001*np.cos(10*t))/2501)-(12*np.exp(-t/5)/12505)
plt.figure()
plt.title("Sinusoid Response of (c)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, c2, label=r'$\omega$ = 10')
plt.legend(loc='upper left')
plt.show()
t = np.arange(0, 4*np.pi/100, 0.001)
c3 = ((4*(300*np.sin(100*t))+100001*np.cos(100*t))/250001)-(12*np.exp(-t/5)/1250005)
plt.figure()
plt.title("Sinusoid Response of (c)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, c3, label=r'$\omega$ = 100')
plt.legend(loc='upper left')
plt.show()

# d1 = (s / (s^2 + 1^2)) * (((20 + 5 * s) * (20 + s)) / s)
# d2 = (s / (s^2 + 10^2)) * (((20 + 5 * s) * (20 + s)) / s)
# d3 = (s / (s^2 + 100^2)) * (((20 + 5 * s) * (20 + s)) / s)

t = np.arange(0, 4*np.pi/1, 0.001)
d1 = 5*(signal.unit_impulse(1)+79*np.sin(t)+24*np.cos(t))
plt.figure()
plt.title("Sinusoid Response of (d)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, d1, label=r'$\omega$ = 1')
plt.legend(loc='upper left')
plt.show()
t = np.arange(0, 4*np.pi/10, 0.001)
d2 = 5*(signal.unit_impulse(1)-2*np.sin(10*t)+24*np.cos(10*t))
plt.figure()
plt.title("Sinusoid Response of (d)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, d2, label=r'$\omega$ = 10')
plt.legend(loc='upper left')
plt.show()
t = np.arange(0, 4*np.pi/100, 0.001)
d3 = 5*signal.unit_impulse(1)-496*np.sin(100*t)-120*np.cos(100*t)
plt.figure()
plt.title("Sinusoid Response of (d)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, d3, label=r'$\omega$ = 100')
plt.legend(loc='upper left')
plt.show()

# e1 = (s / (s^2 + 1^2)) * ((30 * (10 + s)) / ((200 + 2 * s) * (1000 + 2 * s)))
# e2 = (s / (s^2 + 10^2)) * ((30 * (10 + s)) / ((200 + 2 * s) * (1000 + 2 * s)))
# e3 = (s / (s^2 + 100^2)) * ((30 * (10 + s)) / ((200 + 2 * s) * (1000 + 2 * s)))

t = np.arange(0, 4*np.pi/1, 0.001)
e1 = 30*((-1225*np.exp(-500*t)/2000008)+(45*np.exp(-100*t)/80008)+(500590*np.cos(t)-43999*np.sin(t))/10001040004)
plt.figure()
plt.title("Sinusoid Response of (e)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, e1, label=r'$\omega$ = 1')
plt.legend(loc='upper left')
plt.show()
t = np.arange(0, 4*np.pi/10, 0.001)
e2 = 30*((-49*np.exp(-500*t)/80032)+(9*np.exp(-100*t)/16160)+(559*np.cos(10*t)-439*np.sin(10*t))/10104040)
plt.figure()
plt.title("Sinusoid Response of (e)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, e2, label=r'$\omega$ = 10')
plt.legend(loc='upper left')
plt.show()
t = np.arange(0, 4*np.pi/100, 0.001)
e3 = 30*((-49*np.exp(-500*t)/83200)+(9*np.exp(-100*t)/32000)+(32*np.cos(100*t)-17*np.sin(100*t))/104000)
plt.figure()
plt.title("Sinusoid Response of (e)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, e3, label=r'$\omega$ = 100')
plt.legend(loc='upper left')
plt.show()

# f1 = (s / (s^2 + 1^2)) * ((100 * s) / ((100 + 5 * s) * (100 + s)^2))
# f2 = (s / (s^2 + 10^2)) * ((100 * s) / ((100 + 5 * s) * (100 + s)^2))
# f3 = (s / (s^2 + 100^2)) * ((100 * s) / ((100 + 5 * s) * (100 + s)^2))

np.seterr('ignore')
t = np.arange(0, 4*np.pi/1, 0.001)
f1 = ((5*np.exp(-100*t))*(-8020802000*t+100020001*np.exp(80*t)-3196480*np.exp(100*t)*np.sin(t)+223984*np.exp(100*t)*np.cos(t)-100243985))/160432081604
plt.figure()
plt.title("Sinusoid Response of (f)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, f1, label=r'$\omega$ = 1')
plt.legend(loc='upper left')
plt.show()
t = np.arange(0, 4*np.pi/10, 0.001)
f2 = ((1/4080400)*np.exp(-100*t))*(-1010000*t+10201*np.exp(80*t)-2848*np.exp(100*t)*np.sin(10*t)+2224*np.exp(100*t)*np.cos(10*t)-12425)
plt.figure()
plt.title("Sinusoid Response of (f)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, f2, label=r'$\omega$ = 10')
plt.legend(loc='upper left')
plt.show()
t = np.arange(0, 4*np.pi/100, 0.001)
f3 = ((np.exp(-100*t))*(-5200*t+5*np.exp(80*t)+40*np.exp(100*t)*np.sin(100*t)+8*np.exp(100*t)*np.cos(100*t)-13))/41600
plt.figure()
plt.title("Sinusoid Response of (f)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, f3, label=r'$\omega$ = 100')
plt.legend(loc='upper left')
plt.show()

# g1 = (s / (s^2 + 1^2)) * ((200 + 2 * s) / ((50 + 5 * s) * (1000 + s)))
# g2 = (s / (s^2 + 10^2)) * ((200 + 2 * s) / ((50 + 5 * s) * (1000 + s)))
# g3 = (s / (s^2 + 100^2)) * ((200 + 2 * s) / ((50 + 5 * s) * (1000 + s)))

t = np.arange(0, 4*np.pi/1, 0.001)
g1 = (-4000*np.exp(-1000*t)/11000011)-(4*np.exp(-10*t)/1111)+(2*(901*np.sin(t)+9910*np.cos(t))/5000005)
plt.figure()
plt.title("Sinusoid Response of (g)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, g1, label=r'$\omega$ = 1')
plt.legend(loc='upper left')
plt.show()
t = np.arange(0, 4*np.pi/10, 0.001)
g2 = (-40*np.exp(-1000*t)/110011)-(np.exp(-10*t)/550)+((911*np.sin(10*t)+1091*np.cos(10*t))/500050)
plt.figure()
plt.title("Sinusoid Response of (g)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, g2, label=r'$\omega$ = 10')
plt.legend(loc='upper left')
plt.show()
t = np.arange(0, 4*np.pi/100, 0.001)
g3 = (-2*np.exp(-1000*t)/5555)-(np.exp(-10*t)/27775)+((np.sin(100*t)+np.cos(100*t))/2525)
plt.figure()
plt.title("Sinusoid Response of (g)")
plt.axhline(color='black', linestyle='dashed')
plt.xlabel("t [s]")
plt.ylabel("y(t)")
plt.grid(linestyle='dashed')
plt.plot(t, g3, label=r'$\omega$ = 100')
plt.legend(loc='upper left')
plt.show()
